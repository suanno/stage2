# %%
import os
import shutil
import time
import numpy as np
from matplotlib import pyplot as plt

# %%
dt = 0.1
tspan = 10000
N = int(tspan/dt)
Cs = np.zeros(N)
ts = np.linspace(0,tspan,N)

# %%
# Create evolution directory
name = "fileCin.dat"
dir = "../" + name
# Copy files
f = open(dir, "w")
for i in np.arange(0,N):
    T = 25
    Cs[i] = 1 + 0.5*np.sin(2*np.pi*ts[i]/T)
    #Cs[i] = 1
    f.write(str(ts[i]) + " " + str(Cs[i]) + "\n")
f.close()

plt.plot(ts, Cs)
