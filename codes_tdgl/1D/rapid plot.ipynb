# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import os
import shutil
import time

# %%
T = 1   # Period of C(t)

# %%
f = open("fileAveout.dat", "r")
N = 1000000000
x = np.zeros(N)
y = np.zeros(N)
i = 0
for row in f:
    a, b = row.split(" ")
    if 0 == 0:
        x[i] = float(a)
        y[i] = float(b)
        i = i + 1
plt.loglog(x[0:i], y[0:i])

plt.xlabel("t")
plt.ylabel("u[nT]")
plt.title("Crank-Nicolson method\n dt=0.008\n $C(t) = \sin(2\pi t)$")
# Out:
# Text(0.5, 1.0, 'Crank-Nicolson method\n dt=0.008\n $C(t) = \\sin(2\\pi t)$')

# %% [markdown]
# # Plot final state

# %%
f = open("tdgl_result.dat", "r")
N = 1000000000
x = np.zeros(N)
y = np.zeros(N)
i = 0
for row in f:
    if i != 0:
        a, b = row.split(" ")
        x[i-1] = float(a)
        y[i-1] = float(b)
    i = i + 1


#eps = 0.5
plt.plot(x[0:i-1], y[0:i-1])
#plt.ylim(-1-eps,1+eps)
# Out:
# (-1.5, 1.5)

# %%
x
# Out:
# array([0. , 0.1, 0.2, ..., 0. , 0. , 0. ])
