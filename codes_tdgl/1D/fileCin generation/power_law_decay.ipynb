# %%
import os
import shutil
import time
import numpy as np
from matplotlib import pyplot as plt

# %%
def C(t, a, b, alpha0):
    t0 = 1/(2*a*alpha0**2)
    return -(0.5/(t - t0))*(1+b/a)

# %%
a = -2
b = 1
beta0 = 1
alpha0 = beta0/np.sqrt(b)

# %%
# Create evolution directory
dt = 0.001
tspan = 1000
N = int(tspan/dt)
Cs = np.zeros(N)
ts = np.linspace(0,tspan,N)

name = "fileCin.dat"
dir = "../" + name
# Copy files

# %%
f = open(dir, "w")
for i in np.arange(0,N):
    Cs[i] = C(ts[i],a,b,alpha0)
    f.write(str(ts[i]) + " " + str(Cs[i]) + "\n")
f.close()

# %%
plt.plot(ts, Cs)
